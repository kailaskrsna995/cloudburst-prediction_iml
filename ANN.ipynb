# %%
from google.colab import drive
import pandas as pd

# Mount Google Drive
drive.mount('/content/drive')

# Define file path in Google Drive
file_path = "/content/drive/My Drive/cleaned_encoded.csv"
df=pd.read_csv(file_path)
# Out:
# Mounted at /content/drive

# %%
print(df.min())
print(df.max())
# Out:
# Location                    0.067132
# MinimumTemperature         -5.950000
# MaximumTemperature          2.700000
# Rainfall                    0.000000
# Evaporation                 2.022000
# Sunshine                    5.977944
# WindGustSpeed               8.500000
# WindSpeed9am                0.000000
# WindSpeed3pm                0.000000
# Humidity9am                18.000000
# Humidity3pm                 0.000000
# Pressure9am              1001.050000
# Pressure3pm               998.650000
# Cloud9am                    0.000000
# Cloud3pm                    1.000000
# Temperature9am             -1.500000
# Temperature3pm              2.450000
# CloudBurst Today            0.000000
# CloudBurstTomorrow          0.000000
# Year                     2007.000000
# Month                       1.000000
# Day                         1.000000
# WindGustDirection_sin      -1.000000
# WindGustDirection_cos      -1.000000
# WindDirection9am_sin       -1.000000
# WindDirection9am_cos       -1.000000
# WindDirection3pm_sin       -1.000000
# WindDirection3pm_cos       -1.000000
# dtype: float64
# Location                    0.363908
# MinimumTemperature         30.450000
# MaximumTemperature         43.500000
# Rainfall                    1.500000
# Evaporation                 7.296667
# Sunshine                   10.333234
# WindGustSpeed              68.500000
# WindSpeed9am               37.000000
# WindSpeed3pm               40.500000
# Humidity9am               100.000000
# Humidity3pm               100.000000
# Pressure9am              1034.250000
# Pressure3pm              1031.850000
# Cloud9am                    9.000000
# Cloud3pm                    9.000000
# Temperature9am             35.300000
# Temperature3pm             40.450000
# CloudBurst Today            1.000000
# CloudBurstTomorrow          1.000000
# Year                     2017.000000
# Month                      12.000000
# Day                        31.000000
# WindGustDirection_sin       1.000000
# WindGustDirection_cos       1.000000
# WindDirection9am_sin        1.000000
# WindDirection9am_cos        1.000000
# WindDirection3pm_sin        1.000000
# WindDirection3pm_cos        1.000000
# dtype: float64

# %%
import matplotlib.pyplot as plt

df.hist(figsize=(15,10))
plt.tight_layout()
plt.show()

# %%
print(df.mean())
print(df.std())
# Out:
# Location                    0.219146
# MinimumTemperature         12.194318
# MaximumTemperature         23.225174
# Rainfall                    0.392597
# Evaporation                 5.000822
# Sunshine                    7.922535
# WindGustSpeed              39.702391
# WindSpeed9am               13.951313
# WindSpeed3pm               18.574162
# Humidity9am                68.933565
# Humidity3pm                51.539116
# Pressure9am              1017.678987
# Pressure3pm              1015.275746
# Cloud9am                    4.447461
# Cloud3pm                    4.544125
# Temperature9am             16.991751
# Temperature3pm             21.685738
# CloudBurst Today            0.219167
# CloudBurstTomorrow          0.219146
# Year                     2012.769751
# Month                       6.399615
# Day                        15.712258
# WindGustDirection_sin      -0.089295
# WindGustDirection_cos      -0.044828
# WindDirection9am_sin        0.014822
# WindDirection9am_cos        0.085493
# WindDirection3pm_sin        0.001829
# WindDirection3pm_cos       -0.066866
# dtype: float64
# Location                  0.063915
# MinimumTemperature        6.364469
# MaximumTemperature        7.067566
# Rainfall                  0.606057
# Evaporation               1.581644
# Sunshine                  1.386787
# WindGustSpeed            12.174677
# WindSpeed9am              8.555341
# WindSpeed3pm              8.442182
# Humidity9am              18.703607
# Humidity3pm              20.471189
# Pressure9am               6.568425
# Pressure3pm               6.528868
# Cloud9am                  2.265604
# Cloud3pm                  2.026092
# Temperature9am            6.440803
# Temperature3pm            6.812734
# CloudBurst Today          0.413683
# CloudBurstTomorrow        0.413669
# Year                      2.537684
# Month                     3.427262
# Day                       8.794789
# WindGustDirection_sin     0.730558
# WindGustDirection_cos     0.675507
# WindDirection9am_sin      0.668463
# WindDirection9am_cos      0.738671
# WindDirection3pm_sin      0.711234
# WindDirection3pm_cos      0.699771
# dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler

# Drop target column before scaling
X = df.drop(['CloudBurstTomorrow'], axis=1)
y = df['CloudBurstTomorrow']

# Scale features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix

# %%
# Features and Target
X = df.drop(['CloudBurstTomorrow'], axis=1)
y = df['CloudBurstTomorrow']

# Scale features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Split data
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %%
model = Sequential([
    Dense(64, input_dim=X_train.shape[1], activation='relu'),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')  # Binary classification
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=32,
                    validation_split=0.2, verbose=1)
# Out:
# Epoch 1/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8198 - loss: 0.4029 - val_accuracy: 0.8416 - val_loss: 0.3636
# Epoch 2/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8451 - loss: 0.3559 - val_accuracy: 0.8439 - val_loss: 0.3624
# Epoch 3/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.8470 - loss: 0.3513 - val_accuracy: 0.8484 - val_loss: 0.3529
# Epoch 4/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.8477 - loss: 0.3514 - val_accuracy: 0.8477 - val_loss: 0.3526
# Epoch 5/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.8477 - loss: 0.3484 - val_accuracy: 0.8497 - val_loss: 0.3505
# Epoch 6/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8505 - loss: 0.3440 - val_accuracy: 0.8490 - val_loss: 0.3490
# Epoch 7/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.8501 - loss: 0.3439 - val_accuracy: 0.8490 - val_loss: 0.3481
# Epoch 8/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8517 - loss: 0.3417 - val_accuracy: 0.8485 - val_loss: 0.3497
# Epoch 9/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8516 - loss: 0.3404 - val_accuracy: 0.8487 - val_loss: 0.3483
# Epoch 10/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.8511 - loss: 0.3417 - val_accuracy: 0.8516 - val_loss: 0.3457
# Epoch 11/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8539 - loss: 0.3366 - val_accuracy: 0.8503 - val_loss: 0.3446
# Epoch 12/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.8524 - loss: 0.3375 - val_accuracy: 0.8505 - val_loss: 0.3477
# Epoch 13/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8535 - loss: 0.3366 - val_accuracy: 0.8510 - val_loss: 0.3447
# Epoch 14/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8547 - loss: 0.3341 - val_accuracy: 0.8496 - val_loss: 0.3447
# Epoch 15/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.8542 - loss: 0.3359 - val_accuracy: 0.8502 - val_loss: 0.3464
# Epoch 16/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8556 - loss: 0.3338 - val_accuracy: 0.8497 - val_loss: 0.3454
# Epoch 17/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.8533 - loss: 0.3347 - val_accuracy: 0.8498 - val_loss: 0.3485
# Epoch 18/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.8559 - loss: 0.3306 - val_accuracy: 0.8505 - val_loss: 0.3445
# Epoch 19/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8585 - loss: 0.3280 - val_accuracy: 0.8498 - val_loss: 0.3447
# Epoch 20/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.8557 - loss: 0.3317 - val_accuracy: 0.8515 - val_loss: 0.3446
# Epoch 21/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8572 - loss: 0.3287 - val_accuracy: 0.8529 - val_loss: 0.3419
# Epoch 22/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8568 - loss: 0.3279 - val_accuracy: 0.8506 - val_loss: 0.3479
# Epoch 23/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.8586 - loss: 0.3280 - val_accuracy: 0.8525 - val_loss: 0.3422
# Epoch 24/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.8598 - loss: 0.3238 - val_accuracy: 0.8524 - val_loss: 0.3436
# Epoch 25/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 12s 3ms/step - accuracy: 0.8569 - loss: 0.3295 - val_accuracy: 0.8511 - val_loss: 0.3444
# Epoch 26/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.8594 - loss: 0.3261 - val_accuracy: 0.8518 - val_loss: 0.3434
# Epoch 27/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.8578 - loss: 0.3269 - val_accuracy: 0.8535 - val_loss: 0.3423
# Epoch 28/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.8592 - loss: 0.3242 - val_accuracy: 0.8529 - val_loss: 0.3433
# Epoch 29/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8573 - loss: 0.3272 - val_accuracy: 0.8516 - val_loss: 0.3425
# Epoch 30/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.8609 - loss: 0.3237 - val_accuracy: 0.8504 - val_loss: 0.3437
# Epoch 31/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8583 - loss: 0.3262 - val_accuracy: 0.8516 - val_loss: 0.3433
# Epoch 32/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8594 - loss: 0.3221 - val_accuracy: 0.8518 - val_loss: 0.3403
# Epoch 33/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.8605 - loss: 0.3192 - val_accuracy: 0.8515 - val_loss: 0.3432
# Epoch 34/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.8617 - loss: 0.3186 - val_accuracy: 0.8509 - val_loss: 0.3418
# Epoch 35/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.8598 - loss: 0.3215 - val_accuracy: 0.8525 - val_loss: 0.3424
# Epoch 36/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8615 - loss: 0.3182 - val_accuracy: 0.8524 - val_loss: 0.3417
# Epoch 37/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8588 - loss: 0.3224 - val_accuracy: 0.8488 - val_loss: 0.3553
# Epoch 38/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.8614 - loss: 0.3210 - val_accuracy: 0.8523 - val_loss: 0.3401
# Epoch 39/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.8639 - loss: 0.3160 - val_accuracy: 0.8517 - val_loss: 0.3423
# Epoch 40/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8624 - loss: 0.3182 - val_accuracy: 0.8512 - val_loss: 0.3460
# Epoch 41/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.8601 - loss: 0.3201 - val_accuracy: 0.8538 - val_loss: 0.3413
# Epoch 42/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8615 - loss: 0.3178 - val_accuracy: 0.8508 - val_loss: 0.3431
# Epoch 43/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8624 - loss: 0.3168 - val_accuracy: 0.8497 - val_loss: 0.3440
# Epoch 44/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.8598 - loss: 0.3205 - val_accuracy: 0.8530 - val_loss: 0.3428
# Epoch 45/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.8624 - loss: 0.3178 - val_accuracy: 0.8525 - val_loss: 0.3423
# Epoch 46/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.8594 - loss: 0.3187 - val_accuracy: 0.8506 - val_loss: 0.3447
# Epoch 47/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8644 - loss: 0.3142 - val_accuracy: 0.8518 - val_loss: 0.3448
# Epoch 48/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8604 - loss: 0.3204 - val_accuracy: 0.8523 - val_loss: 0.3424
# Epoch 49/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8626 - loss: 0.3162 - val_accuracy: 0.8530 - val_loss: 0.3432
# Epoch 50/50
# 2910/2910 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.8629 - loss: 0.3161 - val_accuracy: 0.8527 - val_loss: 0.3446

# %%
# Accuracy on test set
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.4f}")

# Predict and report
y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)

print(classification_report(y_test, y_pred_classes))
# Out:
# 910/910 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8455 - loss: 0.3473
# Test Accuracy: 0.8481
# 910/910 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.90     22672
#            1       0.68      0.58      0.63      6420
#
#     accuracy                           0.85     29092
#    macro avg       0.78      0.75      0.77     29092
# weighted avg       0.84      0.85      0.84     29092

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Accuracy Plot
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Accuracy', marker='o')
plt.title('Model Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Loss Plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title('Model Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
#overfitting

# %%
#ROC
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Predict probabilities for test set
y_prob = model.predict(X_test)

# Compute ROC curve and AUC
fpr, tpr, _ = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

# Plotting the ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # random guess line
plt.xlabel('False Positive Rate')
plt.ylabel
# Out:
# 910/910 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# <function matplotlib.pyplot.ylabel(ylabel: 'str', fontdict: 'dict[str, Any] | None' = None, labelpad: 'float | None' = None, *, loc: "Literal['bottom', 'center', 'top'] | None" = None, **kwargs) -> 'Text'>

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# Predict on test set
y_prob = model.predict(X_test)
y_pred = (y_prob > 0.5).astype(int)

# Classification Report
print(classification_report(y_test, y_pred))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
# Out:
# 910/910 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.90     22672
#            1       0.68      0.58      0.63      6420
#
#     accuracy                           0.85     29092
#    macro avg       0.78      0.75      0.77     29092
# weighted avg       0.84      0.85      0.84     29092

# %%
# Count values of each class
print(df['CloudBurstTomorrow'].value_counts())

# Or use percentages for better clarity
print(df['CloudBurstTomorrow'].value_counts(normalize=True) * 100)
# Out:
# CloudBurstTomorrow
# 0    113583
# 1     31877
# Name: count, dtype: int64
# CloudBurstTomorrow
# 0    78.085384
# 1    21.914616
# Name: proportion, dtype: float64
